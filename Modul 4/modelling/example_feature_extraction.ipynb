# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
# Contoh gambar
img_path = './dataset/test/chihuahua/img_0_516.jpg'
plt.imshow(plt.imread(img_path))
plt.title('Contoh Gambar Chihuahua')
plt.axis('off')
plt.show()

# %%
img = tf.keras.preprocessing.image.load_img(img_path, target_size=(128, 128))
img_array = tf.keras.preprocessing.image.img_to_array(img) / 255.0
img_array = np.expand_dims(img_array, axis=0)

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2))
])

# %%
# Layer 0
feature_extractor = tf.keras.Model(inputs=model.inputs, outputs=model.layers[0].output) 
features = feature_extractor.predict(img_array)

plt.figure(figsize=(10, 10))
for i in range(32):
    plt.subplot(6, 6, i + 1)
    plt.imshow(features[0, :, :, i], cmap='viridis')
    plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %%
# Layer 1
feature_extractor = tf.keras.Model(inputs=model.inputs, outputs=model.layers[1].output)
features = feature_extractor.predict(img_array)

plt.figure(figsize=(10, 10))
for i in range(32):
    plt.subplot(6, 6, i + 1)
    plt.imshow(features[0, :, :, i], cmap='viridis')
    plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 33ms/step

# %%
# Layer 2
feature_extractor = tf.keras.Model(inputs=model.inputs, outputs=model.layers[2].output)
features = feature_extractor.predict(img_array)

plt.figure(figsize=(10, 10))
for i in range(32):
    plt.subplot(6, 6, i + 1)
    plt.imshow(features[0, :, :, i], cmap='viridis')
    plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 24ms/step

# %%
# Layer 3
feature_extractor = tf.keras.Model(inputs=model.inputs, outputs=model.layers[3].output)
features = feature_extractor.predict(img_array)

plt.figure(figsize=(10, 10))
for i in range(32):
    plt.subplot(6, 6, i + 1)
    plt.imshow(features[0, :, :, i], cmap='viridis')
    plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 31ms/step

# %%
# Layer 4
feature_extractor = tf.keras.Model(inputs=model.inputs, outputs=model.layers[4].output)
features = feature_extractor.predict(img_array)

plt.figure(figsize=(10, 10))
for i in range(32):
    plt.subplot(6, 6, i + 1)
    plt.imshow(features[0, :, :, i], cmap='viridis')
    plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 25ms/step

# %%
# Layer 5
feature_extractor = tf.keras.Model(inputs=model.inputs, outputs=model.layers[5].output)
features = feature_extractor.predict(img_array)

plt.figure(figsize=(10, 10))
for i in range(32):
    plt.subplot(6, 6, i + 1)
    plt.imshow(features[0, :, :, i], cmap='viridis')
    plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 51ms/step
